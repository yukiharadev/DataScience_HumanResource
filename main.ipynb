# %%
from src.plots.plot_charts import plot_training_effectiveness
from src.plots.plot_charts import plot_age_distribution
from src.dbs.db_connect import get_db_connection
from src.plots.plot_charts import plot_department_distribution
from src.plots.plot_charts import plot_performance_reviews
from src.plots.plot_charts import plot_employee_tenure

# %%
db = get_db_connection()
# Out:
# Connected to the database

# %%
plot_department_distribution(db)
# Out:
# department_id
# 673ab3f3b687df36d0eb8064    17
# 673ab3f3b687df36d0eb8063    14
# 673ab3f3b687df36d0eb8065    11
# 673ab3f3b687df36d0eb8060    10
# 673ab3f3b687df36d0eb8061     9
# 673ab3f3b687df36d0eb8062     9
# Name: count, dtype: int64

# %%
plot_age_distribution(db)

# %%
plot_performance_reviews(db)

# %%
plot_training_effectiveness(db)

# %%
plot_employee_tenure(db)
